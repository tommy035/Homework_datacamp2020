# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#1 โหลด csv เข้าไปใน Python Pandas
df = pd.read_csv('wine.csv', names = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids','Nonflavanoid phenols'
                                     ,'Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline'])
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
#2 เขียนโค้ดแสดง หัว10แถว ท้าย10แถว และสุ่ม10แถว
df.head(10)
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
# 5      1    14.20        1.76  2.45               15.2        112
# 6      1    14.39        1.87  2.45               14.6         96
# 7      1    14.06        2.15  2.61               17.6        121
# 8      1    14.83        1.64  2.17               14.0         97
# 9      1    13.86        1.35  2.27               16.0         98
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# ...

# %%
df.tail(10)
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 168      3    13.58        2.58  2.69               24.5        105
# 169      3    13.40        4.60  2.86               25.0        112
# 170      3    12.20        3.03  2.32               19.0         96
# 171      3    12.77        2.39  2.28               19.5         86
# 172      3    14.16        2.51  2.48               20.0         91
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 168           1.55        0.84                  0.39             1.54
# 169           1.98        0.96                  0.27             1.11
# ...

# %%
df.sample(10)
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 115      2    11.03        1.51  2.20               21.5         85
# 14       1    14.38        1.87  2.38               12.0        102
# 60       2    12.33        1.10  2.28               16.0        101
# 56       1    14.22        1.70  2.30               16.3        118
# 84       2    11.84        0.89  2.58               18.0         94
# 5        1    14.20        1.76  2.45               15.2        112
# 107      2    12.72        1.75  2.28               22.5         84
# 22       1    13.71        1.86  2.36               16.6        101
# 75       2    11.66        1.88  1.92               16.0         97
# 72       2    13.49        1.66  2.24               24.0         87
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 115           2.46        2.17                  0.52             2.01
# 14            3.30        3.64                  0.29             2.96
# ...

# %%
#3 เช็คว่ามีข้อมูลที่หายไปไหม สามารถจัดการได้ตามความเหมาะสม
fig = plt.figure(figsize=(12,10))
sns.heatmap(df.isnull(),cbar = False, cmap='Accent')

# %%
#4 ใช้ info และ describe อธิบายข้อมูลเบื้องต้น
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Class                         178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malic acid                    178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcalinity of ash             178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
#  10  Color intensity               178 non-null    float64
#  11  Hue                           178 non-null    float64
# ...

# %%
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
#5 ใช้ pairplot ดูความสัมพันธ์เบื้องต้นของ features ที่สนใจ
sns.pairplot(data=df)

# %%
#6 ใช้ displot เพื่อดูการกระจายของแต่ละคอลัมน์
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Alcohol'],kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Malic acid'],kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Ash'],kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Alcalinity of ash'],kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Magnesium'],kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Total phenols'],kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Flavanoids'],kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Nonflavanoid phenols'],kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Proanthocyanins'],kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Color intensity'],kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Hue'],kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['OD280/OD315 of diluted wines'],kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Proline'],kde=False, bins=50)

# %%
#7 ใช้ heatmap ดูความสัมพันธ์ของคอลัมน์ที่สนใจ
fig = plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True)

# %%
#8 สร้าง scatter plot ของความสัมพันธ์ที่มี Correlation สูงสุด
fig = plt.figure(figsize=(10,8))
sns.scatterplot(x=df['Flavanoids'], y=df['Total phenols'], data=df)

# %%
#9 สร้าง scatter plot ของความสัมพันธ์ที่มี Correlation ต่ำสุด
fig = plt.figure(figsize=(10,8))
sns.scatterplot(x=df['Ash'], y=df['OD280/OD315 of diluted wines'], data=df)

# %%
#10 สร้าง histogram ของ feature ที่สนใจ
plt.hist(x=df['Flavanoids'], bins=30)
plt.show()

# %%
plt.hist(x=df['Ash'], bins=30)
plt.show()

# %%
plt.hist(x=df['Proanthocyanins'], bins=30)
plt.show()

# %%
plt.hist(x=df['Color intensity'], bins=30)
plt.show()

# %%
#11 สร้าง box plot ของ features ที่สนใจ
sns.boxplot(x='Class', y='Magnesium', data=df)

# %%
sns.boxplot(x='Class', y='Ash', data=df)

# %%
sns.boxplot(x='Class', y='Hue', data=df)

# %%
sns.boxplot(x='Class', y='Alcalinity of ash', data=df)

# %%
#13 ทำ Data Visualization อื่นๆ (แล้วแต่เลือก)
sns.barplot(x=df['Class'], y=df['Total phenols'],data=df)
