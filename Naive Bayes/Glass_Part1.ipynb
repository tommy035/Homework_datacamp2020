# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#1 โหลด csv เข้าไปใน Python Pandas
df = pd.read_csv('glass.csv')
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
#2 เขียนโค้ดแสดง หัว10แถว ท้าย10แถว และสุ่ม10แถว
df.head(10)
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.00     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00     1
# 5  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26     1
# 6  1.51743  13.30  3.60  1.14  73.09  0.58  8.17  0.0  0.00     1
# 7  1.51756  13.15  3.61  1.05  73.24  0.57  8.24  0.0  0.00     1
# 8  1.51918  14.04  3.58  1.37  72.08  0.56  8.30  0.0  0.00     1
# 9  1.51755  13.00  3.60  1.36  72.99  0.57  8.40  0.0  0.11     1

# %%
df.tail(10)
# Out:
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 204  1.51617  14.95  0.0  2.27  73.30  0.00  8.71  0.67  0.0     7
# 205  1.51732  14.95  0.0  1.80  72.99  0.00  8.61  1.55  0.0     7
# 206  1.51645  14.94  0.0  1.87  73.11  0.00  8.67  1.38  0.0     7
# 207  1.51831  14.39  0.0  1.82  72.86  1.41  6.47  2.88  0.0     7
# 208  1.51640  14.37  0.0  2.74  72.85  0.00  9.45  0.54  0.0     7
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %%
df.sample(10)
# Out:
#           RI     Na    Mg    Al     Si     K     Ca    Ba    Fe  Type
# 111  1.52739  11.02  0.00  0.75  73.08  0.00  14.96  0.00  0.00     2
# 162  1.52211  14.19  3.78  0.91  71.36  0.23   9.14  0.00  0.37     3
# 17   1.52196  14.36  3.85  0.89  71.36  0.15   9.15  0.00  0.00     1
# 54   1.51778  13.21  2.81  1.29  72.98  0.51   9.02  0.00  0.09     1
# 49   1.51898  13.58  3.35  1.23  72.08  0.59   8.91  0.00  0.00     1
# 184  1.51115  17.38  0.00  0.34  75.41  0.00   6.65  0.00  0.00     6
# 148  1.51670  13.24  3.57  1.38  72.70  0.56   8.44  0.00  0.10     3
# 39   1.52213  14.21  3.82  0.47  71.77  0.11   9.57  0.00  0.00     1
# 198  1.51531  14.38  0.00  2.66  73.10  0.04   9.08  0.64  0.00     7
# 134  1.51811  13.33  3.85  1.25  72.78  0.52   8.12  0.00  0.00     2

# %%
#3 เช็คว่ามีข้อมูลที่หายไปไหม สามารถจัดการได้ตามความเหมาะสม
fig = plt.figure(figsize=(12,10))
sns.heatmap(df.isnull(), cbar=True, cmap='terrain')

# %%
#4 ใช้ info และ describe อธิบายข้อมูลเบื้องต้น
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516523   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
#5 ใช้ pairplot ดูความสัมพันธ์เบื้องต้นของ features ที่สนใจ
sns.pairplot(data=df[['RI','Na','Mg','Al','Si','Ca']])

# %%
#6 ใช้ displot เพื่อดูการกระจายของแต่ละคอลัมน์
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Si'], kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Na'], kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Al'], kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['Fe'], kde=False, bins=50)

# %%
fig = plt.figure(figsize=(8,6))
sns.distplot(df['RI'], kde=False, bins=50)

# %%
#7 ใช้ heatmap ดูความสัมพันธ์ของคอลัมน์ที่สนใจ
fig = plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True)

# %%
#8 สร้าง scatter plot ของความสัมพันธ์ที่มี Correlation สูงสุด
fig = plt.figure(figsize=(10,8))
sns.scatterplot(x=df['Ca'], y=df['RI'], data=df)

# %%
#9 สร้าง scatter plot ของความสัมพันธ์ที่มี Correlation ต่ำสุด
fig = plt.figure(figsize=(10,8))
sns.scatterplot(x=df['RI'], y=df['Ba'], data=df)

# %%
#10 สร้าง histogram ของ feature ที่สนใจ
plt.hist(x=df['RI'], bins=30)
plt.show()

# %%
plt.hist(x=df['Al'], bins=30)
plt.show()

# %%
plt.hist(x=df['Ca'], bins=30)
plt.show()

# %%
plt.hist(x=df['Mg'], bins=30)
plt.show()

# %%
#11 สร้าง box plot ของ features ที่สนใจ
sns.boxplot(data=df, x=df['Type'], y=df['Al'])

# %%
sns.boxplot(data=df, x=df['Type'], y=df['Si'])

# %%
sns.boxplot(data=df, x=df['Type'], y=df['Mg'])

# %%
sns.boxplot(data=df, x=df['Type'], y=df['RI'])
